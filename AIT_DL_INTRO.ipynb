# %% [markdown]
# <a href="https://colab.research.google.com/github/athan37/AIT-Deeplearning/blob/main/AIT_DL_INTRO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://assetstorev1-prd-cdn.unity3d.com/key-image/bc9fdf76-fd87-413c-896d-b5c5958a1daa.png -O img.jpg
# Out:
# --2023-02-15 13:33:30--  https://assetstorev1-prd-cdn.unity3d.com/key-image/bc9fdf76-fd87-413c-896d-b5c5958a1daa.png
# Resolving assetstorev1-prd-cdn.unity3d.com (assetstorev1-prd-cdn.unity3d.com)... 184.84.128.49
# Connecting to assetstorev1-prd-cdn.unity3d.com (assetstorev1-prd-cdn.unity3d.com)|184.84.128.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1218763 (1.2M) [image/png]
# Saving to: ‘img.jpg’
#
# img.jpg             100%[===================>]   1.16M  --.-KB/s    in 0.06s
#
# 2023-02-15 13:33:30 (18.0 MB/s) - ‘img.jpg’ saved [1218763/1218763]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('img.jpg')
plt.imshow(img)

# %%
import numpy as np
img2 = np.asarray(img).copy()

for i in range(30):
  for j in range(30):
    img2[i][j] = [0, 0, 0, 255]

plt.imshow(img2)
